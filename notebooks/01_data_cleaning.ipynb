# %% [markdown]
# # Data Cleaning Pipeline
# ## Supermarket Analytics Assignment
#
# This notebook demonstrates the data cleaning and preprocessing steps for the supermarket transaction datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys

# Add parent directory to path for imports
sys.path.append('..')
from src.data_preprocessing import SupermarketDataPreprocessor

# %% [markdown]
# ## Load Raw Datasets

# %%
# Initialize the preprocessor
preprocessor = SupermarketDataPreprocessor(data_dir="../data/raw")

# Load all datasets
preprocessor.load_data()

print("Raw Dataset Shapes:")
print(f"Items: {preprocessor.items_df.shape}")
print(f"Sales: {preprocessor.sales_df.shape}")
print(f"Promotions: {preprocessor.promotion_df.shape}")
print(f"Supermarkets: {preprocessor.supermarkets_df.shape}")

# %% [markdown]
# ## Data Quality Assessment

# %%
# Check data quality before cleaning
print("ITEMS DATASET:")
print("Missing values:")
print(preprocessor.items_df.isnull().sum())
print("\nData types:")
print(preprocessor.items_df.dtypes)
print("\nSample data:")
print(preprocessor.items_df.head())

# %%
print("SALES DATASET:")
print("Missing values:")
print(preprocessor.sales_df.isnull().sum())
print("\nData types:")
print(preprocessor.sales_df.dtypes)
print("\nBasic statistics:")
print(preprocessor.sales_df.describe())

# %% [markdown]
# ## Data Cleaning Process

# %%
# Perform data cleaning
preprocessor.clean_data()

print("After cleaning:")
print(f"Items: {preprocessor.items_df.shape}")
print(f"Sales: {preprocessor.sales_df.shape}")
print(f"Promotions: {preprocessor.promotion_df.shape}")
print(f"Supermarkets: {preprocessor.supermarkets_df.shape}")

# %% [markdown]
# ## Dataset Integration and Feature Engineering

# %%
# Merge all datasets
merged_data = preprocessor.merge_datasets()
print(f"Merged dataset shape: {merged_data.shape}")

# Create additional features
final_data = preprocessor.create_features()
print(f"Final dataset with features: {final_data.shape}")
print("\nFinal columns:")
print(final_data.columns.tolist())

# %% [markdown]
# ## Data Quality Validation

# %%
# Final data quality checks
print("Final data quality summary:")
print(f"Total records: {len(final_data):,}")
print(f"Missing values per column:")
missing_counts = final_data.isnull().sum()
print(missing_counts[missing_counts > 0])

# Save processed data
preprocessor.save_processed_data()
print("\nProcessed data saved successfully!")

# %% [markdown]
# ## Summary
#
# The data cleaning pipeline successfully:
# 1. Loaded and validated all four source datasets
# 2. Cleaned data quality issues (missing values, duplicates, data types)
# 3. Merged datasets using proper relationships
# 4. Created engineered features for machine learning
# 5. Saved the final processed dataset for analysis
#
# The cleaned dataset is ready for exploratory analysis and machine learning modeling.
